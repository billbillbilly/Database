# %%
from google.colab import drive
drive.mount('/content/drive')
# setup working directory to a folder in Google Drive
import os 
root_dir = "/content/drive/My Drive/"
# set folder name (this folder should exist in 'root_dir')
project_folder = "multisensory_data/"

def set_working_directory(project_folder):
  # change the OS to use your project folder as the working directory
  os.chdir(root_dir + project_folder)
  print('\nYour working directory was changed to ' + root_dir + project_folder + \
        "\n\nYou can also run !pwd to confirm the current working directory." )

set_working_directory(project_folder)

# %%
! pip install gdown

# %% [markdown]
# # Download datasets in your current work directory
#
# ## You actually do not need to download all

# %%
# 360-degree dataset in AA
! gdown https://drive.google.com/uc?id=1apd1u57-_RDpSicF1ewbjOeX-QcXhUBd
# spectrograms AA
! gdown https://drive.google.com/uc?id=1f8X0MXPGBV_RcGsSkefVVYQ4F6CUbfTy
# pretrained model for image segementation
! gdown https://drive.google.com/uc?id=1oQ1vtcsX8p2TwoVoVXNLzON4I8kuPgU4
# ESC-50 dataset for sound classification
! gdown https://drive.google.com/uc?id=1nDAUHXx3XjP7IFv1c5oD23axxFJUReHK
